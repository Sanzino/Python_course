# %% [markdown]
# # 📘 Lecture 2 - Data structures
#
# Part 2: Tuples
#
# **Course: Introduction to Computing Using Python
# **Date: 16.01.2026
# **Week / Lecture #: Week 2 - Lecture 2
#
# ---
#
# ## 🎯 Learning Objectives
# - Understand what tuple is in Python
# - Create tuples and store multiple values
# - Acess tuple elements using indexing and slicing
# - Understanding tuple immutability
# - Compare tuples and lists

# %% [markdown]
# ## 🧠 Concept Explanation (in my own words)
#
# Describe the topic in your own words:
# - What is this about?
# - Why is it important?
# - When or where is it used?

# %%
# Code example / demonstration

# %% [markdown]
# ## 📝 Key Takeaways
# -
# -

# %% [markdown]
# ## ❓ Questions / Topics to Review
# -
# -
