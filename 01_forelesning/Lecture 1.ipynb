# %% [markdown]
# # 📘 Python Basics - variables, Data Types & functions
#
# Course:Introduction to Computing Using Python
# Date:15.01.2026
# Week / Lecture #: Week 1 - Lecture 1
#
#
# ---
#
# ## 🎯 Learning Objectives
# - understading basics Python syntax and expressions
# - Learn how variables store values
# - Identify core data types (int, float, string, boolean)
# - Use built-in modules such as math
# - Define and call simple functions

# %% [markdown]
# ## 🧠 Concept Explanation (in my own words)
#
# Describe the topic in your own words:
#
# What is this about?
# Python basics introduce how to write simple instructions using variables, data types, expressions, and functions.
#
# Why is this important?
# These concepts are the foundation of all Python programs. Without understanding them, it is impossible to work with data structures, libraries, or real applications.
#
# When is this used?
# Python basics are used every time we write code, from simple scripts to data analysis and automation.

# %%
# Code example / demonstration

# Variables
x = 5
y = 10
z = x + y

# Data types
a = 3.14
name = "Python"
is_active = True

# Boolean expressions
x > y
x == 5

# Using math module
import math
math.sqrt(16)

# Function
def hyp(a, b):
    return math.sqrt(a**2 + b**2)

hyp(3, 4)

# %% [markdown]
# ## 📝 Key Takeaways
# Python Basics – Summary
#
# Python is an interpreted, high-level programming language
#
# Variables store values in memory
#
# Python has basic data types like int, float, string, and boolean
#
# Boolean expressions return True or False
#
# Modules must be imported before use
#
# Functions allow code reuse

# %% [markdown]
# ## ❓ Questions / Topics to Review
# -
# -
